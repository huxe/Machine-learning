# %%
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv('Insurance.csv') #Fatch data

# %%
age=data.drop('buy',axis=1)

# %%
spliter,accur=[],[]
for i in range(1,21):
    spliter.append(i*0.04)
    train_x,test_x,train_y,test_y=train_test_split(age,data.buy,test_size=i*0.04)
    model=LogisticRegression()
    model.fit(train_x,train_y)
    y_pred=model.predict(test_x)
    train_Acc = model.score(train_x, train_y)
    test_Acc = accuracy_score(test_y, y_pred)
    accur.append(train_Acc)
    print("split size ",i*0.04,"\taccuracy ",train_Acc)
# Out:
# split size  0.04 	accuracy  0.88
# split size  0.08 	accuracy  0.875
# split size  0.12 	accuracy  0.8695652173913043
# split size  0.16 	accuracy  0.7727272727272727
# split size  0.2 	accuracy  0.9523809523809523
# split size  0.24 	accuracy  0.95
# split size  0.28 	accuracy  0.8421052631578947
# split size  0.32 	accuracy  0.8333333333333334
# split size  0.36 	accuracy  0.8235294117647058
# split size  0.4 	accuracy  0.875
# split size  0.44 	accuracy  0.7333333333333333
# split size  0.48 	accuracy  0.9285714285714286
# split size  0.52 	accuracy  0.9166666666666666
# split size  0.56 	accuracy  0.8181818181818182
# split size  0.6 	accuracy  0.8
# split size  0.64 	accuracy  0.8888888888888888
# split size  0.68 	accuracy  0.75
# split size  0.72 	accuracy  0.8571428571428571
# split size  0.76 	accuracy  0.5
# split size  0.8 	accuracy  0.6

# %%
# plt.plot(spliter,accur)

from matplotlib import rcParams
rcParams['figure.figsize'] = 15,3
plt.plot(spliter,accur)
plt.xticks(spliter)
plt.xlabel('Spilit Size')
plt.ylabel('Accuracy')
plt.title('Spilit, Accuracy Graph')
# Out:
# Text(0.5,1,'Spilit, Accuracy Graph')
